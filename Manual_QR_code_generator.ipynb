# %%
import qr_signer_app
import qrcode
import json


str = """{"k":"andriod","m":"نمونه پیامی که عمدی دستکاری نشد آست.","s":"fqIKifxY_i4wzUbeDL_SQftCBnNOZ07Re0UbxXdx8kF9LHhuVkk497pSWxi6dZfBkSD-OoK5BgjzkB0cAghpAA"}"""
print(str)
# Out:
# {"k":"andriod","m":"نمونه پیامی که عمدی دستکاری نشد آست.","s":"fqIKifxY_i4wzUbeDL_SQftCBnNOZ07Re0UbxXdx8kF9LHhuVkk497pSWxi6dZfBkSD-OoK5BgjzkB0cAghpAA"}

# %%
img = qrcode.make(str).resize((320, 320))
# save the image
img.save("qrcode.png")
